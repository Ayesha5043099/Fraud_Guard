-- %%
-- Check 1: Koi negative amounts to nahi (invalid data)
SELECT COUNT(*) AS negative_amount_count
FROM workspace.default.feature_transactions
WHERE amount < 0;
